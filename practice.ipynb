# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = {'nom*§$': ['Ali', 'Moussa', 'Omar', 'Maryam', 'Madina', 'Amadou'],
        'age': [25, 30, 18 , 20, 28, 42] 
        }

# %%
df = pd.DataFrame(data)
df
# Out:
#       nom  age
# 0     Ali   25
# 1  Moussa   30
# 2    Omar   18
# 3  Maryam   20
# 4  Madina   28
# 5  Amadou   42

# %%
df.shape
# Out:
# (6, 2)

# %%
df['nom ']
# Out:
# 0       Ali
# 1    Moussa
# 2      Omar
# 3    Maryam
# 4    Madina
# 5    Amadou
# Name: nom , dtype: object

# %%
df.head()
# Out:
#       nom  age
# 0     Ali   25
# 1  Moussa   30
# 2    Omar   18
# 3  Maryam   20
# 4  Madina   28

# %%
df.tail()
# Out:
#       nom  age
# 1  Moussa   30
# 2    Omar   18
# 3  Maryam   20
# 4  Madina   28
# 5  Amadou   42

# %%
df.shape
# Out:
# (6, 2)

# %%
df.shape[0]
# Out:
# 6

# %%
df.shape[1]
# Out:
# 2

# %%
df.columns
# Out:
# Index(['nom', 'age'], dtype='object')

# %%
df['age'].describe()
# Out:
# count     6.000000
# mean     27.166667
# std       8.588752
# min      18.000000
# 25%      21.250000
# 50%      26.500000
# 75%      29.500000
# max      42.000000
# Name: age, dtype: float64

# %%
df['genre'] = ['Masculin','Masculin','Masculin','Masculin','Feminin','Masculin']

# %%
df
# Out:
#    prenom  age genre
# 0     Ali   25     M
# 1  Moussa   30     M
# 2    Omar   18     M
# 3  Maryam   20     M
# 4  Madina   28     F
# 5  Amadou   42     M

# %%
df['genre'].value_counts()
# Out:
# genre
# M    5
# F    1
# Name: count, dtype: int64

# %%
df['genre'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['genre'].nunique()
# Out:
# 2

# %%
df.rename(columns={'nom': 'prenom'}, inplace=True)

# %%
df
# Out:
#    prenom  age genre
# 0     Ali   25     M
# 1  Moussa   30     M
# 2    Omar   18     M
# 3  Maryam   20     M
# 4  Madina   28     F
# 5  Amadou   42     M

# %%
df.dtypes.value_counts()
# Out:
# object    2
# int64     1
# Name: count, dtype: int64

# %%
df.drop(columns=['age'], inplace=True)

# %%
df
# Out:
#    prenom genre
# 0     Ali     M
# 1  Moussa     M
# 2    Omar     M
# 3  Maryam     M
# 4  Madina     F
# 5  Amadou     M

# %%
df.insert(1, 'nom', ['Diop', 'Sarr','Ba','Ka', 'Fall', 'Sall'])

# %%
df
# Out:
#    prenom   nom genre
# 0     Ali  Diop     M
# 1  Moussa  Sarr     M
# 2    Omar    Ba     M
# 3  Maryam    Ka     M
# 4  Madina  Fall     F
# 5  Amadou  Sall     M

# %%
df.sort_values(by='genre')
# Out:
#    prenom   nom genre
# 4  Madina  Fall     F
# 0     Ali  Diop     M
# 1  Moussa  Sarr     M
# 2    Omar    Ba     M
# 3  Maryam    Ka     M
# 5  Amadou  Sall     M

# %%
df['age'] = [25, 30, 18 , 20, 28, 42]

# %%
df
# Out:
#       NOM   nom  AGE  age
# 0     Ali  Diop   25   25
# 1  Moussa  Sarr   30   30
# 2    Omar    Ba   18   18
# 3  Maryam    Ka   20   20
# 4  Madina  Fall   28   28
# 5  Amadou  Sall   42   42

# %%
df.sort_values(by='age', ascending=False, ignore_index=True)
# Out:
#    prenom   nom genre  age
# 0  Amadou  Sall     M   42
# 1  Moussa  Sarr     M   30
# 2  Madina  Fall     F   28
# 3     Ali  Diop     M   25
# 4  Maryam    Ka     M   20
# 5    Omar    Ba     M   18

# %%
df.select_dtypes(include=['int', 'float'])
# Out:
#    age
# 0   25
# 1   30
# 2   18
# 3   20
# 4   28
# 5   42

# %%
df.select_dtypes(include='number')
# Out:
#    age
# 0   25
# 1   30
# 2   18
# 3   20
# 4   28
# 5   42

# %%
df.select_dtypes(exclude='number')
# Out:
#    prenom   nom genre
# 0     Ali  Diop     M
# 1  Moussa  Sarr     M
# 2    Omar    Ba     M
# 3  Maryam    Ka     M
# 4  Madina  Fall     F
# 5  Amadou  Sall     M

# %%
df.select_dtypes(exclude='O')
# Out:
#    age
# 0   25
# 1   30
# 2   18
# 3   20
# 4   28
# 5   42

# %%
df.select_dtypes('O')
# Out:
#    prenom   nom genre
# 0     Ali  Diop     M
# 1  Moussa  Sarr     M
# 2    Omar    Ba     M
# 3  Maryam    Ka     M
# 4  Madina  Fall     F
# 5  Amadou  Sall     M

# %%
df.columns = df.columns.str.title()

# %%
df
# Out:
#    Prenom   Nom Genre  Age
# 0     Ali  Diop     M   25
# 1  Moussa  Sarr     M   30
# 2    Omar    Ba     M   18
# 3  Maryam    Ka     M   20
# 4  Madina  Fall     F   28
# 5  Amadou  Sall     M   42

# %%
df.columns = df.columns.str.lower()
df
# Out:
#    prenom   nom genre  age
# 0     Ali  Diop     M   25
# 1  Moussa  Sarr     M   30
# 2    Omar    Ba     M   18
# 3  Maryam    Ka     M   20
# 4  Madina  Fall     F   28
# 5  Amadou  Sall     M   42

# %%
df.columns = df.columns.str.upper()
df
# Out:
#       NOM  AGE
# 0     Ali   25
# 1  Moussa   30
# 2    Omar   18
# 3  Maryam   20
# 4  Madina   28
# 5  Amadou   42

# %%
df.columns = df.columns.str.strip()
df
# Out:
#       nom  age
# 0     Ali   25
# 1  Moussa   30
# 2    Omar   18
# 3  Maryam   20
# 4  Madina   28
# 5  Amadou   42

# %%
df.columns = df.columns.str.strip().str.title()

# %%
df
# Out:
#       NOM   nom  AGE  age     genre
# 0     Ali  Diop   25   25  Masculin
# 1  Moussa  Sarr   30   30  Masculin
# 2    Omar    Ba   18   18  Masculin
# 3  Maryam    Ka   20   20  Masculin
# 4  Madina  Fall   28   28   Feminin
# 5  Amadou  Sall   42   42  Masculin

# %%
df['genre']
# Out:
# 0    Masculin
# 1    Masculin
# 2    Masculin
# 3    Masculin
# 4     Feminin
# 5    Masculin
# Name: genre, dtype: object

# %%
df.iloc[:,-1]
# Out:
# 0    Masculin
# 1    Masculin
# 2    Masculin
# 3    Masculin
# 4     Feminin
# 5    Masculin
# Name: genre, dtype: object

# %%
df.describe()
# Out:
#              age
# count   6.000000
# mean   27.166667
# std     8.588752
# min    18.000000
# 25%    21.250000
# 50%    26.500000
# 75%    29.500000
# max    42.000000

# %%
df['age'].describe()
# Out:
# count     6.000000
# mean     27.166667
# std       8.588752
# min      18.000000
# 25%      21.250000
# 50%      26.500000
# 75%      29.500000
# max      42.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
# Analyse du dataset titanic avec le graphique FacetGrid

# %%
sns.get_dataset_names()

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# df.drop(columns=['pclass', 'alive', 'who','embarked', 'alone','adult_male'], inplace=True)
df
# Out:
#      survived     sex   age  sibsp  parch     fare   class deck  embark_town
# 0           0    male  22.0      1      0   7.2500   Third  NaN  Southampton
# 1           1  female  38.0      1      0  71.2833   First    C    Cherbourg
# 2           1  female  26.0      0      0   7.9250   Third  NaN  Southampton
# 3           1  female  35.0      1      0  53.1000   First    C  Southampton
# 4           0    male  35.0      0      0   8.0500   Third  NaN  Southampton
# ..        ...     ...   ...    ...    ...      ...     ...  ...          ...
# 886         0    male  27.0      0      0  13.0000  Second  NaN  Southampton
# 887         1  female  19.0      0      0  30.0000   First    B  Southampton
# 888         0  female   NaN      1      2  23.4500   Third  NaN  Southampton
# 889         1    male  26.0      0      0  30.0000   First    C    Cherbourg
# 890         0    male  32.0      0      0   7.7500   Third  NaN   Queenstown
#
# [891 rows x 9 columns]

# %%
df.select_dtypes(exclude='number').head()
# Out:
#       sex  class deck  embark_town
# 0    male  Third  NaN  Southampton
# 1  female  First    C    Cherbourg
# 2  female  Third  NaN  Southampton
# 3  female  First    C  Southampton
# 4    male  Third  NaN  Southampton

# %%
df.select_dtypes(include='number')
# Out:
#      survived   age  sibsp  parch     fare
# 0           0  22.0      1      0   7.2500
# 1           1  38.0      1      0  71.2833
# 2           1  26.0      0      0   7.9250
# 3           1  35.0      1      0  53.1000
# 4           0  35.0      0      0   8.0500
# ..        ...   ...    ...    ...      ...
# 886         0  27.0      0      0  13.0000
# 887         1  19.0      0      0  30.0000
# 888         0   NaN      1      2  23.4500
# 889         1  26.0      0      0  30.0000
# 890         0  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
df.select_dtypes(include='float')
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# - On souhaite étudier le tarif de voyage par classe en fonction de l’âge des clients (hommes / femmes)

# %%
sns.FacetGrid(df, col='class', hue='sex').map(sns.scatterplot, 'age', 'fare').add_legend();
plt.savefig('test.png')
